# %%
#FaÃ§a um Programa que peÃ§a dois nÃºmeros e imprima o maior deles.
num1 = int(raw_input('Informe um numero: '))
num2 = int(raw_input('Informe outro numero: '))

if (num1 > num2):
    print num1, 'Ã© maior que', num2
elif (num1 < num2):
    print num2, 'Ã© maior que', num1
else:
    print 'Os numeros sao iguais'
# Out:
# Informe um numero: 40
# Informe outro numero: 100
# 100 Ã© maior que 40

# %%
#FaÃ§a um Programa que peÃ§a um valor e mostre na tela se o valor Ã© positivo ou negativo.
num = int(raw_input('Informe um numero: '))

if (num > 0):
    print num, 'Ã© positivo'
elif (num < 0):
    print num, 'Ã© negativo'
else:
    print 'O numero Ã© igual a 0'
# Out:
# Informe um numero: -100
# -100 Ã© negativo

# %%
#FaÃ§a um Programa que verifique se uma letra digitada Ã© "F" ou "M". 
#Conforme a letra escrever: F - Feminino, M - Masculino, Sexo InvÃ¡lido.

sexo = raw_input('Informe F para FEMININO ou M para MASCULINO: ')

if (sexo.upper() == 'M'):
    print 'MASCULINO'
elif (sexo.upper() == 'F'):
    print 'FEMININO'
else:
    print 'Sexo Invalido'
# Out:
# Informe F para FEMININO ou M para MASCULINO: M
# MASCULINO

# %%
#FaÃ§a um Programa que verifique se uma letra digitada Ã© vogal ou consoante.
letra = raw_input('Informe uma letra: ')

if ('AEIOU'.find(letra.capitalize()) >= 0):
    print 'VOGAL'
else:
    print 'CONSOANTE'
# Out:
# Informe uma letra: u
# VOGAL

# %%
'''FaÃ§a um programa para a leitura de duas notas parciais de um aluno.
O programa deve calcular a mÃ©dia alcanÃ§ada por aluno e apresentar:
A mensagem "Aprovado", se a mÃ©dia alcanÃ§ada for maior ou igual a sete;
A mensagem "Reprovado", se a mÃ©dia for menor do que sete;
A mensagem "Aprovado com DistinÃ§Ã£o", se a mÃ©dia for igual a dez.'''

nota1 = float(raw_input('Informe a primeira nota: '))
nota2 = float(raw_input('Informe a segunda nota: '))

media = (nota1 + nota2) / 2.0

print 'A media do aluno eh:', media
if (media == 10):
    print 'Aprovado com Distincao'
elif (media >= 7):
    print 'Aprovado'
else:
    print 'Reprovado'
# Out:
# Informe a primeira nota: 7
# Informe a segunda nota: 8
# A media do aluno eh: 7.5
# Aprovado

# %%
#FaÃ§a um Programa que leia trÃªs nÃºmeros e mostre o maior deles.
num1 = int(raw_input('Informe um numero: '))
num2 = int(raw_input('Informe outro numero: '))
num3 = int(raw_input('Informe mais um numero: '))

if (num1 == num2) and (num1 == num3):
    print 'Os numeros sao iguais'
elif (num1 > num2) and (num1 > num3):
    print 'O maior numero Ã©:', num1
elif (num2 > num3):
    print 'O maior numero Ã©:', num2
else:
    print 'O maior numero Ã©:', num3
# Out:
# Informe um numero: 10
# Informe outro numero: 5
# Informe mais um numero: 60
# O maior numero eh: 60

# %%
#FaÃ§a um Programa que leia trÃªs nÃºmeros e mostre o maior e o menor deles.

num1 = int(raw_input('Informe um numero: '))
num2 = int(raw_input('Informe outro numero: '))
num3 = int(raw_input('Informe mais um numero: '))

if (num1 == num2) and (num1 == num3):
    print 'Os numeros sao iguais'
else:
    if (num1 > num2) and (num1 > num3):
        print 'O maior numero Ã©:', num1
    elif (num2 > num3):
        print 'O maior numero Ã©:', num2
    else:
        print 'O maior numero Ã©:', num3

    if (num1 < num2) and (num1 < num3):
        print 'O menor numero Ã©:', num1
    elif (num2 < num3):
        print 'O menor numero Ã©:', num2
    else:
        print 'O menor numero Ã©:', num3
# Out:
# Informe um numero: 10
# Informe outro numero: 40
# Informe mais um numero: 1
# O maior numero Ã©: 40
# O menor numero Ã©: 1

# %%
#FaÃ§a um programa que pergunte o preÃ§o de trÃªs produtos e informe qual produto vocÃª deve comprar,
#sabendo que a decisÃ£o Ã© sempre pelo mais barato.

num1 = int(raw_input('Informe o primeiro preco: '))
num2 = int(raw_input('Informe o segundo preco: '))
num3 = int(raw_input('Informe o terceiro preco: '))

if (num1 == num2) and (num1 == num3):
    print 'Pode comprar qualquer um, ja que os precos sao iguais.'
elif (num1 < num2) and (num1 < num3):
    print 'Compre pelo primeiro preco'
elif (num2 < num3):
    print 'Compre pelo segundo preco'
else:
    print 'Compre pelo terceiro preco'
# Out:
# Informe o primeiro preco: 50
# Informe o segundo preco: 40
# Informe o terceiro preco: 30
# Compre pelo terceiro preco

# %%
#FaÃ§a um Programa que leia trÃªs nÃºmeros e mostre-os em ordem decrescente.
num1 = int(raw_input('Informe um numero: '))
num2 = int(raw_input('Informe outro numero: '))
num3 = int(raw_input('Informe mais um numero: '))

if (num1 >= num2) and (num1 >= num3):
    print num1
    if (num2 >= num3):
        print num2
        print num3
    else:
        print num3
        print num2
elif (num2 >= num3):
    print num2
    if (num1 >= num3):
        print num1
        print num3
    else:
        print num3
        print num1
else:
    print num3
    if (num1 >= num2):
        print num1
        print num2
    else:
        print num2
        print num1
# Out:
# Informe um numero: 1
# Informe outro numero: 2
# Informe mais um numero: 3
# 3
# 2
# 1

# %%
#FaÃ§a um Programa que pergunte em que turno vocÃª estuda. PeÃ§a para digitar M-matutino ou V-Vespertino ou N- Noturno. 
#Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor InvÃ¡lido!", conforme o caso.
print 'Informe o turno em que voce estuda'
print '[M]atutino'
print '[V]espertino'
print '[N]oturno'
turno = raw_input('Opcao escolhida: ').upper()

if (turno == 'M'):
    print 'Bom dia!'
elif (turno == 'V'):
    print 'Boa tarde!'
elif (turno == 'N'):
    print 'Boa noite!'
else:
    print 'Valor invalido'
# Out:
# Informe o turno em que voce estuda
# [M]atutino
# [V]espertino
# [N]oturno
# Opcao escolhida: N
# Boa noite!

# %%
'''As OrganizaÃ§Ãµes Tabajara resolveram dar um aumento de salÃ¡rio aos seus colaboradores e lhe contraram para desenvolver o programa que calcularÃ¡ os reajustes.
FaÃ§a um programa que recebe o salÃ¡rio de um colaborador e o reajuste segundo o seguinte critÃ©rio, baseado no salÃ¡rio atual:
salÃ¡rios atÃ© R$ 280,00 (incluindo) : aumento de 20%
salÃ¡rios entre R$ 280,00 e R$ 700,00 : aumento de 15%
salÃ¡rios entre R$ 700,00 e R$ 1500,00 : aumento de 10%
salÃ¡rios de R$ 1500,00 em diante : aumento de 5% ApÃ³s o aumento ser realizado, informe na tela:
o salÃ¡rio antes do reajuste;
o percentual de aumento aplicado;
o valor do aumento;
o novo salÃ¡rio, apÃ³s o aumento.'''

salario = float(raw_input('Informe o valor do salario do colaborador: '))

if (salario <= 280):
    percentual = 20
elif (salario <= 700):
    percentual = 15
elif (salario <= 1500):
    percentual = 10
else:
    percentual = 5

aumento = salario * (percentual / 100.0)
novoSalario = salario + aumento

print 'Salario antes do reajuste:', salario
print 'Percentual de aumento:', percentual, '%'
print 'Valor do aumento:', aumento
print 'Novo Salario:', novoSalario
# Out:
# Informe o valor do salario do colaborador: 2000
# Salario antes do reajuste: 2000.0
# Percentual de aumento: 5 %
# Valor do aumento: 100.0
# Novo Salario: 2100.0

# %%
'''FaÃ§a um programa para o cÃ¡lculo de uma folha de pagamento, sabendo que os descontos sÃ£o do Imposto de Renda, que depende do salÃ¡rio bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do SalÃ¡rio Bruto, mas nÃ£o Ã© descontado (Ã© a empresa que deposita). O SalÃ¡rio LÃ­quido corresponde ao SalÃ¡rio Bruto menos os descontos. O programa deverÃ¡ pedir ao usuÃ¡rio o valor da sua hora e a quantidade de horas trabalhadas no mÃªs.
Desconto do IR:
SalÃ¡rio Bruto atÃ© 900 (inclusive) - isento
SalÃ¡rio Bruto atÃ© 1500 (inclusive) - desconto de 5%
SalÃ¡rio Bruto atÃ© 2500 (inclusive) - desconto de 10%
SalÃ¡rio Bruto acima de 2500 - desconto de 20% Imprima na tela as informaÃ§Ãµes, dispostas conforme o exemplo abaixo. No exemplo o valor da hora Ã© 5 e a quantidade de hora Ã© 220.'''
# Solicita os dados
valorPorHora = float(raw_input('Informe o valor da hora trabalhada: '))
quantidadeHoras =\
    float(raw_input('Informe a quantidade de horas trabalhadas no mes:'))

# Calcula o salario bruto
salarioBruto = valorPorHora * quantidadeHoras

# Calcula o imposto de renda
if (salarioBruto > 2500):
    aliquotaIR = 20
elif (salarioBruto > 1500):
    aliquotaIR = 10
elif (salarioBruto > 900):
    aliquotaIR = 5
else:
    aliquotaIR = 0

valorIR = salarioBruto * (aliquotaIR / 100.0)

# Calcula o valor para o sindicato
valorSindicato = salarioBruto * (3 / 100.0)

# Calcula o total de descontos
totalDescontos = valorIR + valorSindicato

# Calcula o valor do FGTS
valorFGTS = salarioBruto * (11 / 100.0)

# Calcula o salario liquido
salarioLiquido = salarioBruto - totalDescontos

# Imprime o resultado
print 'Salario Bruto: (', valorPorHora, '*', quantidadeHoras, '): R$',\
    salarioBruto
print '(-) IR (', aliquotaIR, '%): R$', valorIR
print '(-) Sindicato ( 3 %): R$', valorSindicato
print 'FGTS ( 11 %): R$', valorFGTS
print 'Total de Descontos: R$', totalDescontos
print 'Salario Liquido: R$', salarioLiquido
# Out:
# Informe o valor da hora trabalhada: 60
# Informe a quantidade de horas trabalhadas no mes:160
# Salario Bruto: ( 60.0 * 160.0 ): R$ 9600.0
# (-) IR ( 20 %): R$ 1920.0
# (-) Sindicato ( 3 %): R$ 288.0
# FGTS ( 11 %): R$ 1056.0
# Total de Descontos: R$ 2208.0
# Salario Liquido: R$ 7392.0

# %%
#FaÃ§a um Programa que leia um nÃºmero e exiba o dia correspondente da semana. (1-Domingo, 2- Segunda, etc.),
#se digitar outro valor deve aparecer valor invÃ¡lido.

numero_dia = int(raw_input('Informe um numero para saber o dia da semana: '))

if (numero_dia == 1):
    print 'Domingo'
elif (numero_dia == 2):
    print 'Segunda'
elif (numero_dia == 3):
    print 'Terca'
elif (numero_dia == 4):
    print 'Quarta'
elif (numero_dia == 5):
    print 'Quinta'
elif (numero_dia == 6):
    print 'Sexta'
elif (numero_dia == 7):
    print 'Sabado'
else:
    print 'Valor invalido'
# Out:
# Informe um numero para saber o dia da semana: 1
# Domingo

# %%
'''FaÃ§a um programa que lÃª as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre,
e calcule a sua mÃ©dia. 
A atribuiÃ§Ã£o de conceitos obedece Ã  tabela abaixo:
  MÃ©dia de Aproveitamento  Conceito
  Entre 9.0 e 10.0        A
  Entre 7.5 e 9.0         B
  Entre 6.0 e 7.5         C
  Entre 4.0 e 6.0         D
  Entre 4.0 e zero        E
O algoritmo deve mostrar na tela as notas, a mÃ©dia, o conceito correspondente e a mensagem âAPROVADOâ se o conceito for A, B ou C
ou âREPROVADOâ se o conceito for D ou E.'''
ota1 = float(raw_input('Informe o valor da primeira nota: '))
nota2 = float(raw_input('Informe o valor da segunda nota: '))

media = (nota1 + nota2) / 2

if (media < 4):
    print 'Conceito: E'
    aprovado = False
elif (media < 6):
    print 'Conceito: D'
    aprovado = False
elif (media < 7.5):
    print 'Conceito: C'
    aprovado = True
elif (media < 9):
    print 'Conceito: B'
    aprovado = True
else:
    print 'Conceito: A'
    aprovado = True

if (aprovado):
    print 'APROVADO'
else:
    print 'REPROVADO'
# Out:
# Informe o valor da primeira nota: 7
# Informe o valor da segunda nota: 5
# Conceito: C
# APROVADO

# %%
'''FaÃ§a um Programa que peÃ§a os 3 lados de um triÃ¢ngulo. O programa deverÃ¡ informar se os valores podem ser um triÃ¢ngulo.
Indique, caso os lados formem um triÃ¢ngulo, se o mesmo Ã©: equilÃ¡tero, isÃ³sceles ou escaleno.
Dicas:
TrÃªs lados formam um triÃ¢ngulo quando a soma de quaisquer dois lados for maior que o terceiro;
TriÃ¢ngulo EquilÃ¡tero: trÃªs lados iguais;
TriÃ¢ngulo IsÃ³sceles: quaisquer dois lados iguais;
TriÃ¢ngulo Escaleno: trÃªs lados diferentes;'''

print 'Informe os valores dos lados do triangulo'
lado1 = float(raw_input('Lado 1: '))
lado2 = float(raw_input('Lado 2: '))
lado3 = float(raw_input('Lado 3: '))

# Verifica se eh um triangulo
if (lado1 > (lado2 + lado3)) or (lado2 > (lado1 + lado3))\
        or (lado3 > (lado1 + lado2)):
    ehTriangulo = False
else:
    ehTriangulo = True

if (ehTriangulo):
    print 'Os valores formam um Triangulo'
    # Verifica o tipo de triangulo
    if (lado1 == lado2) and (lado2 == lado3):
        print 'Triangulo Equilatero'
    elif (lado1 == lado2) or (lado1 == lado2) or (lado2 == lado3):
        print 'Triangulo Isosceles'
    else:
        print 'Triangulo Escaleno'
else:
    print 'Os valores nao formam um Triangulo'
# Out:
# Informe os valores dos lados do triangulo
# Lado 1: 10
# Lado 2: 10
# Lado 3: 10
# Os valores formam um Triangulo
# Triangulo Equilatero

# %%
'''FaÃ§a um programa que calcule as raÃ­zes de uma equaÃ§Ã£o do segundo grau, na forma ax2 + bx + c.
O programa deverÃ¡ pedir os valores de a, b e c e fazer as consistÃªncias, informando ao usuÃ¡rio nas seguintes situaÃ§Ãµes:
Se o usuÃ¡rio informar o valor de A igual a zero, a equaÃ§Ã£o nÃ£o Ã© do segundo grau e o programa nÃ£o deve fazer pedir os
demais valores, sendo encerrado;
Se o delta calculado for negativo, a equaÃ§Ã£o nÃ£o possui raizes reais. Informe ao usuÃ¡rio e encerre o programa;
Se o delta calculado for igual a zero a equaÃ§Ã£o possui apenas uma raiz real; informe-a ao usuÃ¡rio;
Se o delta for positivo, a equaÃ§Ã£o possui duas raiz reais; informe-as ao usuÃ¡rio;'''

import math

print 'Calculo de equacao de Segundo Grau'
valorA = float(raw_input('Informe o valor de a : '))
valorB = float(raw_input('Informe o valor de b : '))
valorC = float(raw_input('Informe o valor de c : '))

# Verifica se eh uma equacao de segundo grau
if (valorA == 0):
    print 'Os valores nao formam uma equacao de segundo grau'
else:
    # Calcula o Delta
    delta = math.pow(valorB, 2) - (4 * valorA * valorC)

    if (delta < 0):
        print 'A equacao nao possui valores reais.'
    elif (delta == 0):
        print 'A equacao possui apenas uma raiz'
        raiz = -(valorB) / (2 * valorA)
        print 'Raiz:', raiz
    else:
        print 'A equacao possui duas raizes'
        raiz1 = (-(valorB) + math.sqrt(delta)) / (2 * valorA)
        raiz2 = (-(valorB) - math.sqrt(delta)) / (2 * valorA)
        print 'Raiz 1:', raiz1
        print 'Raiz 2:', raiz2
# Out:
# Calculo de equacao de Segundo Grau
# Informe o valor de a : 1
# Informe o valor de b : 10
# Informe o valor de c : 0
# A equacao possui duas raizes
# Raiz 1: 0.0
# Raiz 2: -10.0

# %%
#FaÃ§a um Programa que peÃ§a um nÃºmero correspondente a um determinado ano e em seguida informe se este ano Ã© ou nÃ£o bissexto.
ano = int(raw_input('Informe um ano: '))

bissexto = False
if (ano % 4==0 and ano % 100!=0 or ano % 400==0):
    bissexto = True
else:
    bissexto = False

if (bissexto):
    print 'O ano Ã© BISSEXTO'
else:
    print 'O ano nÃ£o Ã© BISSEXTO'
# Out:
# Informe um ano: 2000
# O ano Ã© BISSEXTO

# %%
#FaÃ§a um Programa que peÃ§a uma data no formato dd/mm/aaaa e determine se a mesma Ã© uma data vÃ¡lida.

data = raw_input('Informe uma data no formato dd/mm/yyyy: ')

dia = int(data[0:2])
mes = int(data[3:5])
ano = int(data[6:])

print dia, mes, ano

bissexto = False
if (ano % 4==0 and ano % 100!=0 or ano % 400==0):
    bissexto = True
else:
    bissexto = False

valida = True

if (mes in (1, 3, 5, 7, 8, 10, 12)):
    if (dia < 1) or (dia > 31):
        valida = False
elif (mes in (4, 6, 9, 11)):
    if (dia < 1) or (dia > 30):
        valida = False
else:
    if (bissexto):
        if (dia < 1) or (dia > 29):
            valida = False
    else:
        if (dia < 1) or (dia > 28):
            valida = False

if (valida):
    print 'Data VALIDA'
else:
    print 'Data INVALIDA'
# Out:
# Informe uma data no formato dd/mm/yyyy: 29/02/2019
# 29 2 2019
# Data INVALIDA

# %%
'''FaÃ§a um Programa que leia um nÃºmero inteiro menor que 1000 e imprima a quantidade de centenas, dezenas e unidades do mesmo.
Observando os termos no plural a colocaÃ§Ã£o do "e", da vÃ­rgula entre outros. Exemplo:
326 = 3 centenas, 2 dezenas e 6 unidades
12 = 1 dezena e 2 unidades Testar com: 326, 300, 100, 320, 310,305, 301, 101, 311, 111, 25, 20, 10, 21, 11, 1, 7 e 16'''

num = int(raw_input('Informe um numero inteiro: '))

if num < 1000:
    centenas = num / 100
    dezenas = (num - (centenas * 100)) / 10
    unidades = (num - (centenas * 100) - (dezenas * 10))

    saida = ''
    if (centenas > 0):
        saida = saida + str(centenas)
        if (centenas > 1):
            saida = saida + ' centenas '
        else:
            saida = saida + ' centena '

    if (dezenas > 0):
        if (unidades == 0) and (centenas != 0):
            saida = saida + 'e '
        saida = saida + str(dezenas)
        if (dezenas > 1):
            saida = saida + ' dezenas '
        else:
            saida = saida + ' dezena '

    if (unidades > 0):
        if (centenas != 0) or (dezenas != 0):
            saida = saida + 'e '
        saida = saida + str(unidades)
        if (unidades > 1):
            saida = saida + ' unidades'
        else:
            saida = saida + ' unidade'

    print saida
else:
    print("NÃºmero maior que 1000!, tente novamente")
# Out:
# Informe um numero inteiro: 191
# 1 centena 9 dezenas e 1 unidade

# %%
'''FaÃ§a um Programa para leitura de trÃªs notas parciais de um aluno. O programa deve calcular a mÃ©dia alcanÃ§ada por aluno e presentar:
A mensagem "Aprovado", se a mÃ©dia for maior ou igual a 7, com a respectiva mÃ©dia alcanÃ§ada;
A mensagem "Reprovado", se a mÃ©dia for menor do que 7, com a respectiva mÃ©dia alcanÃ§ada;
A mensagem "Aprovado com DistinÃ§Ã£o", se a mÃ©dia for igual a 10.'''

nota1 = float(raw_input('Informe a primeira nota: '))
nota2 = float(raw_input('Informe a segunda nota: '))
nota3 = float(raw_input('Informe a terceira nota: '))

media = (nota1 + nota2 + nota3) / 3.0

print 'Media do aluno: {}'.format(media)
if (media == 10):
    print 'Aprovado com Distincao'
elif (media >= 7):
    print 'Aprovado'
else:
    print 'Reprovado'
# Out:
# Informe a primeira nota: 70
# Informe a segunda nota: 69
# Informe a terceira nota: 80
# Media do aluno: 73.0
# Aprovado

# %%
'''FaÃ§a um Programa para um caixa eletrÃ´nico. O programa deverÃ¡ perguntar ao usuÃ¡rio a valor do saque e depois informar quantas notas de cada valor serÃ£o fornecidas. As notas disponÃ­veis serÃ£o as de 1, 5, 10, 50 e 100 reais. O valor mÃ­nimo Ã© de 10 reais e o mÃ¡ximo de 600 reais. O programa nÃ£o deve se preocupar com a quantidade de notas existentes na mÃ¡quina.
Exemplo 1: Para sacar a quantia de 256 reais, o programa fornece duas notas de 100, uma nota de 50, uma nota de 5 e uma nota de 1;
Exemplo 2: Para sacar a quantia de 399 reais, o programa fornece trÃªs notas de 100, uma nota de 50, quatro notas de 10, uma nota de 5 e quatro notas de 1.'''

valor = int(raw_input('Informe o valor que deseja sacar: '))

if (valor < 10) or (valor > 600):
    print 'Valor invalido para saque'
else:
    notas100 = valor / 100
    notas50 = (valor - (notas100 * 100)) / 50
    notas10 = (valor - (notas100 * 100) - (notas50 * 50)) / 10
    notas5 = (valor - (notas100 * 100) - (notas50 * 50) - (notas10 * 10)) / 5
    notas1 = valor - (notas100 * 100) - (notas50 * 50) -\
        (notas10 * 10) - (notas5 * 5)

    print 'Notas de 100:',notas100
    print 'Notas de  50:',notas50
    print 'Notas de  10:',notas10
    print 'Notas de   5:',notas5
    print 'Notas de   1:',notas1
# Out:
# Informe o valor que deseja sacar: 399
# Notas de 100: 3
# Notas de  50: 1
# Notas de  10: 4
# Notas de   5: 1
# Notas de   1: 4

# %%
#FaÃ§a um Programa que peÃ§a um nÃºmero inteiro e determine se ele Ã© par ou impar. Dica: utilize o operador mÃ³dulo (resto da divisÃ£o).
valor = int(raw_input('Informe um numero: '))

if (valor % 2 == 0):
    print 'numero Ã© par'
else:
    print 'numero Ã© impar'
# Out:
# Informe um numero: 12
# numero Ã© par

# %%
#FaÃ§a um Programa que peÃ§a um nÃºmero e informe se o nÃºmero Ã© inteiro ou decimal. Dica: utilize uma funÃ§Ã£o de arredondamento.
valor = float(raw_input('Informe um numero: '))

if (valor == int(valor)):
    print 'Valor Ã© inteiro'
else:
    print 'Valor Ã© decimal'
# Out:
# Informe um numero: 12.5
# Valor Ã© decimal

# %%
'''FaÃ§a um Programa que leia 2 nÃºmeros e em seguida pergunte ao usuÃ¡rio qual operaÃ§Ã£o ele deseja realizar. O resultado da operaÃ§Ã£o deve ser acompanhado de uma frase que diga se o nÃºmero Ã©:
par ou Ã­mpar;
positivo ou negativo;
inteiro ou decimal.'''
valor = float(raw_input('Informe um numero: '))

print '1 - Par ou Impar'
print '2 - Positivo ou Negativo'
print '3 - Inteiro ou Decimal'
opcao = raw_input('Escolha uma opcao: ')

if (opcao == '1'):
    if (valor % 2 == 0):
        print 'Valor Ã© par'
    else:
        print 'Valor Ã© impar'
elif (opcao == '2'):
    if (valor < 0):
        print 'Valor Ã© negativo'
    elif (valor > 0):
        print 'Valor Ã© positivo'
    else:
        print 'Valor Ã© igual a zero'
elif (opcao == '3'):
    if (valor == int(valor)):
        print 'Valor Ã© inteiro'
    else:
        print 'Valor eh decimal'
else:
    print 'Opcao InvÃ¡lida'
# Out:
# Informe um numero: 13
# 1 - Par ou Impar
# 2 - Positivo ou Negativo
# 3 - Inteiro ou Decimal
# Escolha uma opcao: 1
# Valor Ã© impar

# %%
'''FaÃ§a um programa que faÃ§a 5 perguntas para uma pessoa sobre um crime. As perguntas sÃ£o:
"Telefonou para a vÃ­tima?"
"Esteve no local do crime?"
"Mora perto da vÃ­tima?"
"Devia para a vÃ­tima?"
"JÃ¡ trabalhou com a vÃ­tima?"
O programa deve no final emitir uma classificaÃ§Ã£o sobre a participaÃ§Ã£o da pessoa no crime.
Se a pessoa responder positivamente a 2 questÃµes ela deve ser classificada como "Suspeita", entre 3 e 4 como "CÃºmplice" e 5 como "Assassino".
Caso contrÃ¡rio, ele serÃ¡ classificado como "Inocente".'''

print 'Programa Detetive'
print 'Responda as perguntas abaixo com S (sim) ou N (nao)'

telefonou = raw_input('Voce telefonou para a vitima? ').upper()
localCrime = raw_input('Voce esteve no local do crime? ').upper()
moraPerto = raw_input('Voce mora perto da vitima? ').upper()
devia = raw_input('Voce devia para a vitima? ').upper()
trabalhou = raw_input('Voce trabalhou para a vitima? ').upper()

classificacao = 0

if (telefonou == 'S'):
    classificacao += 1

if (localCrime == 'S'):
    classificacao += 1

if (moraPerto == 'S'):
    classificacao += 1

if (devia == 'S'):
    classificacao += 1

if (trabalhou == 'S'):
    classificacao += 1

if (classificacao < 2):
    print 'Inocente'
elif (classificacao == 2):
    print 'Suspeito'
elif (classificacao <= 4):
    print 'Cumplice'
else:
    print 'Assassino'
# Out:
# Programa Detetive
# Responda as perguntas abaixo com S (sim) ou N (nao)
# Voce telefonou para a vitima? N
# Voce esteve no local do crime? N
# Voce mora perto da vitima? S
# Voce devia para a vitima? N
# Voce trabalhou para a vitima? N
# Inocente

# %%
'''Um posto estÃ¡ vendendo combustÃ­veis com a seguinte tabela de descontos:
Ãlcool:
atÃ© 20 litros, desconto de 3% por litro
acima de 20 litros, desconto de 5% por litro
Gasolina:
atÃ© 20 litros, desconto de 4% por litro
acima de 20 litros, desconto de 6% por litro Escreva um algoritmo que leia o nÃºmero de litros vendidos,
o tipo de combustÃ­vel (codificado da seguinte forma: A-Ã¡lcool, G-gasolina),
calcule e imprima o valor a ser pago pelo cliente sabendo-se que o preÃ§o do litro da gasolina Ã© R$ 2,50
o preÃ§o do litro do Ã¡lcool Ã© R$ 1,90.'''

# Solicita informacoes
tipoCombustivel =\
    raw_input('Informe (A) para Alcool ou (G) para Gasolina: ').upper()
quantidadeLitros = float(raw_input('Informe a quantidade de litros: '))

# Define o valor e os descontos
if (tipoCombustivel == 'A'):
    valor = 1.9
    if (quantidadeLitros <= 20):
        desconto = 3
    else:
        desconto = 5
else:
    valor = 2.5
    if (quantidadeLitros <= 20):
        desconto = 4
    else:
        desconto = 6

# Calcula o total
totalPagar = (valor * quantidadeLitros) * ((100 - desconto) / 100.0)

print 'Total a pagar: ', totalPagar
# Out:
# Informe (A) para Alcool ou (G) para Gasolina: G
# Informe a quantidade de litros: 30
# Total a pagar:  70.5

# %%
'''Uma fruteira estÃ¡ vendendo frutas com a seguinte tabela de preÃ§os:
                      AtÃ© 5 Kg           Acima de 5 Kg
Morango         R$ 2,50 por Kg          R$ 2,20 por Kg
MaÃ§Ã£            R$ 1,80 por Kg          R$ 1,50 por Kg
Se o cliente comprar mais de 8 Kg em frutas ou o valor total da compra ultrapassar R$ 25,00,
receberÃ¡ ainda um desconto de 10% sobre este total.
Escreva um algoritmo para ler a quantidade (em Kg) de morangos e a quantidade (em Kg) de maÃ§as adquiridas e
escreva o valor a ser pago pelo cliente.'''

# Entrada de dados
totalMorangos =\
    float(raw_input('Informe a quantidade (em Kg) de morangos comprados: '))
totalMacas =\
    float(raw_input('Informe a quantidade (em Kg) de macas comprados: '))

# Calcula o valor bruto
if (totalMorangos <= 5):
    valorMorangos = totalMorangos * 2.5
else:
    valorMorangos = totalMorangos * 2.2

if (totalMacas <= 5):
    valorMacas = totalMacas * 1.8
else:
    valorMacas = totalMacas * 1.5

valorBruto = valorMorangos + valorMacas

# Verifica os descontos
if ((totalMorangos + totalMacas) >= 8) or (valorBruto >= 25):
    valorBruto = valorBruto * 0.9

# Imprime o resultado
print 'Valor a pagar: ', valorBruto
# Out:
# Informe a quantidade (em Kg) de morangos comprados: 8
# Informe a quantidade (em Kg) de macas comprados: 5
# Valor a pagar:  23.94

# %%
'''O Hipermercado Tabajara estÃ¡ com uma promoÃ§Ã£o de carnes que Ã© imperdÃ­vel. Confira:
                      AtÃ© 5 Kg           Acima de 5 Kg
File Duplo      R$ 4,90 por Kg          R$ 5,80 por Kg
Alcatra         R$ 5,90 por Kg          R$ 6,80 por Kg
Picanha         R$ 6,90 por Kg          R$ 7,80 por Kg
Para atender a todos os clientes, cada cliente poderÃ¡ levar apenas um dos tipos de carne da promoÃ§Ã£o,
porÃ©m nÃ£o hÃ¡ limites para a quantidade de carne por cliente. 
Se compra for feita no cartÃ£o Tabajara o cliente receberÃ¡ ainda um desconto de 5% sobre o total da compra.
Escreva um programa que peÃ§a o tipo e a quantidade de carne comprada pelo usuÃ¡rio e gere um cupom fiscal,
contendo as informaÃ§Ãµes da compra: 
tipo e quantidade de carne, preÃ§o total, tipo de pagamento, valor do desconto e valor a pagar.'''
# Escolha do tipo da carne
print '1 - File Duplo'
print '2 - Alcatra'
print '3 - Picanha'
tipoCarne = raw_input('Informe o tipo da carne escolhida: ').upper()

# Escolha da quantidade
quantidade = float(raw_input('Informe a quantidade comprada: '))

# Verifica cartao
cartaoTabajara = raw_input('Usara cartao Tabajara (S/N): ').upper()

print 'CUPOM FISCAL'

# Verifica o tipo da carne e calcula o valor bruto
if (tipoCarne == '1'):
    print 'Carne Escolhida: File Duplo'
    if (quantidade <= 5):
        valorBruto = quantidade * 4.9
    else:
        valorBruto = quantidade * 5.8
elif (tipoCarne == '2'):
    print 'Carne Escolhida: Alcatra'
    if (quantidade <= 5):
        valorBruto = quantidade * 5.9
    else:
        valorBruto = quantidade * 6.8
else:
    print 'Carne Escolhida: Picanha'
    if (quantidade <= 5):
        valorBruto = quantidade * 6.9
    else:
        valorBruto = quantidade * 7.8
print 'Valor Bruto', valorBruto

# Verifica se possui desconto
desconto = 0.0
if (cartaoTabajara == 'S'):
    print 'Pagamento com cartao Tabajara'
    desconto = valorBruto * 0.05
else:
    print 'Pagamento nao sera com o cartao Tabajara'
print 'Desconto: ', desconto
print 'Valor a Pagar: ', (valorBruto - desconto)
# Out:
# 1 - File Duplo
# 2 - Alcatra
# 3 - Picanha
# Informe o tipo da carne escolhida: 3
# Informe a quantidade comprada: 12
# Usara cartao Tabajara (S/N): S
# CUPOM FISCAL
# Carne Escolhida: Picanha
# Valor Bruto 93.6
# Pagamento com cartao Tabajara
# Desconto:  4.68
# Valor a Pagar:  88.92
